# %% [markdown]
# ### Запускаем превый сркитп из ролика обучения

# %% [markdown]
# ### С этого начинаем раскопки. На старте не выполнялось

# %%
from pyspark.sql import SparkSession
from send2trash.win.legacy import kernel32

spark = (
    SparkSession
    .builder
    .appName("halltape_pyspark_local")
    .getOrCreate()
)

print("Активные Spark сессии:", spark.sparkContext.uiWebUrl)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pyspark.sql import SparkSession
#       2 import pyspark.sql.functions as F
#       5 spark = (
#       6     SparkSession
#       7     .builder
#       8     .appName("halltape_pyspark_local")
#       9     .getOrCreate()
#      10 )
#
# File P:\Git\kes-spark-playground\.venv\Lib\site-packages\pyspark\__init__.py:71
#      69 from pyspark.util import InheritableThread, inheritable_thread_target
#      70 from pyspark.storagelevel import StorageLevel
# ---> 71 from pyspark.accumulators import Accumulator, AccumulatorParam
#      72 from pyspark.serializers import MarshalSerializer, CPickleSerializer
#      73 from pyspark.taskcontext import TaskContext, BarrierTaskContext, BarrierTaskInfo
#
# File P:\Git\kes-spark-playground\.venv\Lib\site-packages\pyspark\accumulators.py:324
# ...

# %% [markdown]
# ## PySpark environment check
#
# **Date:** 2026-01-09
#
# ### Environment
# - OS: Windows
# - Python: 3.12
# - PySpark: 4.1.0
#
# ### Status
# ❌ Import error on Windows:

# %%
pip show pyspark
# Out:
# Name: pyspark
# Version: 4.1.0
# Summary: Apache Spark Python API
# Home-page: https://github.com/apache/spark/tree/master/python
# Author: Spark Developers
# Author-email: dev@spark.apache.org
# License: Apache-2.0
# Location: P:\Git\kes-spark-playground\.venv\Lib\site-packages
# Requires: py4j
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Удаляем старый и ставим новый

# %%
pip show pyspark
# Out:
# Name: pyspark
# Version: 3.5.1
# Summary: Apache Spark Python API
# Home-page: https://github.com/apache/spark/tree/master/python
# Author: Spark Developers
# Author-email: dev@spark.apache.org
# License: http://www.apache.org/licenses/LICENSE-2.0
# Location: P:\Git\kes-spark-playground\.venv\Lib\site-packages
# Requires: py4j
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.executable
# Out:
# 'P:\\Git\\kes-spark-playground\\.venv\\Scripts\\python.exe'

# %%
pip show pyspark
# Out:
# Name: pyspark
# Version: 4.1.0
# Summary: Apache Spark Python API
# Home-page: https://github.com/apache/spark/tree/master/python
# Author: Spark Developers
# Author-email: dev@spark.apache.org
# License: Apache-2.0
# Location: P:\Git\kes-spark-playground\.venv\Lib\site-packages
# Requires: py4j
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F


spark = (
    SparkSession
    .builder
    .appName("halltape_pyspark_local")
    .getOrCreate()
)

print("Активные Spark сессии:", spark.sparkContext.uiWebUrl)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 9
#       1 from pyspark.sql import SparkSession
#       2 import pyspark.sql.functions as F
#       5 spark = (
#       6     SparkSession
#       7     .builder
#       8     .appName("halltape_pyspark_local")
# ----> 9     .getOrCreate()
#      10 )
#      12 print("Активные Spark сессии:", spark.sparkContext.uiWebUrl)
#
# File P:\Git\kes-spark-playground\.venv\Lib\site-packages\pyspark\sql\session.py:493, in SparkSession.Builder.getOrCreate(self)
#     491 session = SparkSession._instantiatedSession
#     492 if session is None or session._sc._jsc is None:
# --> 493     sparkConf = SparkConf()
#     494     for key, value in self._options.items():
#     495         sparkConf.set(key, value)
#
# ...

# %%
import pyspark
pyspark.__version__
# Out:
# '3.5.1'

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession
    .builder
    .appName("halltape_pyspark_local")
    .getOrCreate()
)

spark
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 7
#       1 from pyspark.sql import SparkSession
#       3 spark = (
#       4     SparkSession
#       5     .builder
#       6     .appName("halltape_pyspark_local")
# ----> 7     .getOrCreate()
#       8 )
#      10 spark
#
# File P:\Git\kes-spark-playground\.venv\Lib\site-packages\pyspark\sql\session.py:493, in SparkSession.Builder.getOrCreate(self)
#     491 session = SparkSession._instantiatedSession
#     492 if session is None or session._sc._jsc is None:
# --> 493     sparkConf = SparkConf()
#     494     for key, value in self._options.items():
#     495         sparkConf.set(key, value)
#
# File P:\Git\kes-spark-playground\.venv\Lib\site-packages\pyspark\conf.py:130, in __init__(self, loadDefaults, _jvm, _jconf)
#     126 from pyspark.context import SparkContext
# ...

# %%
Получается, что нет Java. Надо было ставить. Ставлю Java

# %% [markdown]
# Пробую "на горячую"

# %%
import subprocess

subprocess.run(["java", "-version"], capture_output=True, text=True)
# Out:
# CompletedProcess(args=['java', '-version'], returncode=0, stdout='', stderr='java version "11.0.24" 2024-07-16 LTS\nJava(TM) SE Runtime Environment 18.9 (build 11.0.24+7-LTS-271)\nJava HotSpot(TM) 64-Bit Server VM 18.9 (build 11.0.24+7-LTS-271, mixed mode)\n')

# %%
import os
print(os.environ.get("JAVA_HOME"))
# Out:
# None

# %%
import os
os.environ["JAVA_HOME"] = r"C:\Program Files\Java\jdk-11.0.24"
print(os.environ["JAVA_HOME"])
# Out:
# C:\Program Files\Java\jdk-11.0.24

# %%
import os
print(os.environ.get("JAVA_HOME"))
# Out:
# C:\Program Files\Java\jdk-11.0.24

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
spark
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 2
#       1 from pyspark.sql import SparkSession
# ----> 2 spark = SparkSession.builder.getOrCreate()
#       3 spark
#
# File P:\Git\kes-spark-playground\.venv\Lib\site-packages\pyspark\sql\session.py:493, in SparkSession.Builder.getOrCreate(self)
#     491 session = SparkSession._instantiatedSession
#     492 if session is None or session._sc._jsc is None:
# --> 493     sparkConf = SparkConf()
#     494     for key, value in self._options.items():
#     495         sparkConf.set(key, value)
#
# File P:\Git\kes-spark-playground\.venv\Lib\site-packages\pyspark\conf.py:130, in __init__(self, loadDefaults, _jvm, _jconf)
#     126 from pyspark.context import SparkContext
#     128 _jvm = _jvm or SparkContext._jvm
# --> 130 if _jvm is not None:
# ...

# %% [markdown]
# # Рестарт kernel

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
spark
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 2
#       1 from pyspark.sql import SparkSession
# ----> 2 spark = SparkSession.builder.getOrCreate()
#       3 spark
#
# File P:\Git\kes-spark-playground\.venv\Lib\site-packages\pyspark\sql\session.py:493, in SparkSession.Builder.getOrCreate(self)
#     491 session = SparkSession._instantiatedSession
#     492 if session is None or session._sc._jsc is None:
# --> 493     sparkConf = SparkConf()
#     494     for key, value in self._options.items():
#     495         sparkConf.set(key, value)
#
# File P:\Git\kes-spark-playground\.venv\Lib\site-packages\pyspark\conf.py:130, in __init__(self, loadDefaults, _jvm, _jconf)
#     126 from pyspark.context import SparkContext
#     128 _jvm = _jvm or SparkContext._jvm
# --> 130 if _jvm is not None:
# ...

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://host.docker.internal:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # Конечная проверка результата

# %%
from pyspark.sql import SparkSession
from send2trash.win.legacy import kernel32

spark = (
    SparkSession
    .builder
    .appName("halltape_pyspark_local")
    .getOrCreate()
)

print("Активные Spark сессии:", spark.sparkContext.uiWebUrl)
# Out:
# Активные Spark сессии: http://host.docker.internal:4040
